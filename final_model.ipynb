# %%
# %cd /kaggle/input/project-2/project2
# !pip install torch_geometric
# Out:
# /kaggle/input/project-2/project2
# Requirement already satisfied: torch_geometric in /usr/local/lib/python3.11/dist-packages (2.7.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.11.16)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2025.3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (7.0.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.19.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch_geometric) (3.0.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2025.1.31)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torch_geometric) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torch_geometric) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torch_geometric) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torch_geometric) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torch_geometric) (2024.2.0)

# %%
import argparse
import numpy as np
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from torch_geometric.data import Data

from utils.GNN_data import *
from utils.GNN_architecture import GIN
from utils.train_model import train_model
from utils.evaluate_model import *

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--batch_num', type=int, default=32, help='batch size') 
parser.add_argument('--epoch_num', type=int, default=200, help='Epoch number') 
parser.add_argument('--cover_interval', type=int, default=20, help='Cover interval')
parser.add_argument('--overlap', type=float, default=0.3, help='cover overlap')
parser.add_argument('--save_model_dir', type=str, default='./saved_model', help='saved GNN model directory')
args = parser.parse_args([])

# %%
def load_inp_data(file_path, label):
    nodes, edges = [], []
    
    with open(file_path, 'r') as file:
        lines = file.readlines()

        node_section = False
        element_section = False

        for line in lines:
            line = line.strip()

            if "*Node" in line:
                node_section = True
                element_section = False
                continue

            if "*Element" in line:
                node_section = False
                element_section = True
                continue

            # Skip invalid lines like "*Nset" or "*Elset"
            if "*Nset" in line or "*Elset" in line:
                node_section = False
                element_section = False
                continue

            if node_section:
                parts = line.split(',')
                if len(parts) >= 3:
                    try:
                        x, y = float(parts[1].strip()), float(parts[2].strip())
                        nodes.append([x, y])
                    except ValueError:
                        continue

            if element_section:
                parts = line.split(',')
                if len(parts) >= 3 and parts[0].strip().isdigit() and parts[1].strip().isdigit() and parts[2].strip().isdigit():
                    start, end = int(parts[1].strip()) - 1, int(parts[2].strip()) - 1  # Convert 1-indexed to 0-indexed
                    
                    if start == end:
                        continue
                    
                    # Ensure indices are within valid range
                    if start < len(nodes) and end < len(nodes):
                        edges.append([start, end])
                    else:
                        print(f"Skipping invalid edge ({start+1}, {end+1}) in {file_path}")

    node_tensor = torch.tensor(nodes, dtype=torch.float)
    edge_tensor = torch.tensor(edges, dtype=torch.long).t().contiguous() if edges else torch.empty((2, 0), dtype=torch.long)

    data = Data(x=node_tensor, edge_index=edge_tensor, E=np.float64(label * 200.00))
    return data

# %% [markdown]
# # Data loading

# %%
import os
from glob import glob

folder_list = ['Hexagonal', 'Kagome', 'Demi-A', 'Demi-B', 'Demi-C']
base_path = '.'  

dataset = []

for folder in folder_list:
    results_path = os.path.join(base_path, folder, 'Results.txt')
    inp_folder = os.path.join(base_path, folder, 'inp_files')

    # Parse Results.txt in the current folder
    file_labels = {}
    with open(results_path, 'r') as file:
        for line in file:
            if line.strip() == "" or "E/Es" in line:
                continue
            try:
                file_name, label = line.strip().split(', ')
                filename = file_name.strip().split('.')[0]
                label = float(label)
                file_labels[filename] = label
            except ValueError:
                print(f"[{folder}] Skipping invalid line: {line.strip()}")

    # Load each corresponding .inp file
    for file, label in file_labels.items():
        file_path = os.path.join(inp_folder, f"{file}.inp")
        if os.path.exists(file_path):
            data = load_inp_data(file_path, label)
            if data is not None:
                dataset.append(data)
        else:
            print(f"[{folder}] Missing file: {file_path}")

# %%
dataset
# Out:
# [Data(x=[84, 2], edge_index=[2, 108], E=0.0372903386912),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.0

#  Data(x=[84, 2], edge_index=[2, 108], E=0.0369693033014),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.037293803828),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.0366555725962),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.0373408694904),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.0368161912354),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.0377028918702),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.037464718769000004),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.036671507087),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.0371609723566),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.037315490299200005),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.0370706145072),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.037659350076000006),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.0376438817636),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.0371867663366),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.0370168645076),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.0366406915952),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.0374338482168),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.0369140813526),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.0375745790256),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.0372197915872),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.0374154800546),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.0373787510718),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.036751575976),
#  Data(x=[84, 2], edge_index=[2, 108], E=0.0369315942426),
#  ...]

# %%
batch_size = args.batch_num
epoch_num = args.epoch_num 
learning_rate = 0.001
overlap=args.overlap

# Check if the graph data is directed or undirected. For this study, undirected edges are used.
all_undirected_before = all(is_undirected(data) for data in dataset)
print(f'Graphs are undirected (before conversion): {all_undirected_before}')  # True if all are undirected, False otherwise

# Convert all graphs in the dataset to undirected
dataset = [make_undirected(data) for data in dataset]

# Re-check if all graphs are now undirected
all_undirected_after = all(is_undirected(data) for data in dataset)
print(f'Graphs are undirected (after conversion): {all_undirected_after}')  # True if all are undirected, False otherwise

dataset = normalize_planar_info(dataset)

# Split dataset for train/validation/test
train_loader, test_loader, valid_loader = prepare_dataset(dataset, batch_size, train_percentage=0.80, test_percentage=0.1)
# Out:
# Graphs are undirected (before conversion): False
# Graphs are undirected (after conversion): True
# Number of training graphs: 19804
# Number of test graphs: 2475
# Number of vali graphs: 2476

# %%
dataset[0]
# Out:
# Data(x=[84, 2], edge_index=[2, 216], E=0.0372903386912)

# %%
E_vals = [data.E for data in dataset]

plt.figure(figsize=(5,5), dpi=300) 

plt.rcParams['font.serif'] = ['Times New Roman']
plt.rcParams['font.size'] = 13

labels = ['Hexagonal', 'Kagome', 'Demi-A', 'Demi-B', 'Demi-C']
markers = ['o', 's', '^', 'D', 'x']  # circle, square, triangle, diamond, cross
colors = ['blue', 'green', 'red', 'orange', 'purple']

size = 4951
for i in range(5):
    start = i * size
    end = (i + 1) * size
    x = range(start, end)
    y = E_vals[start:end]
    
    plt.plot(x, y, linestyle='none', marker=markers[i], color=colors[i],
             markersize=3, label=labels[i], alpha=0.4)

plt.ylabel(r'Elastic Modulus $E$ (GPa)')
plt.xlabel('Samples')
plt.xlim(right=25000)
plt.ylim(top=3.5)
plt.legend()
plt.tight_layout()

# %% [markdown]
# # GNN model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
from torch_geometric.nn import GINConv, CGConv, GATv2Conv, TransformerConv, NNConv
from torch_geometric.nn import global_add_pool, global_mean_pool

class Transformer(torch.nn.Module):
    def __init__(self, dim_h, node_feature, heads=4):
        super(Transformer, self).__init__()
        self.conv1 = TransformerConv(node_feature, dim_h, heads=heads)
        self.conv2 = TransformerConv(dim_h * heads, dim_h, heads=heads)
        self.conv3 = TransformerConv(dim_h * heads, dim_h, heads=heads)

        self.lin1 = Linear(dim_h * heads * 3, dim_h * 2)
        self.lin2 = Linear(dim_h * 2, dim_h * 2)
        self.lin3 = Linear(dim_h * 2, 1)
        self.relu = nn.ReLU()

    def forward(self, x, edge_index, batch):
        h1 = self.conv1(x, edge_index)
        h1 = self.relu(h1)
        h2 = self.conv2(h1, edge_index)
        h2 = self.relu(h2)
        h3 = self.conv3(h2, edge_index)
        h3 = self.relu(h3)

        h1 = global_mean_pool(h1, batch)
        h2 = global_mean_pool(h2, batch)
        h3 = global_mean_pool(h3, batch)

        h = torch.cat((h1, h2, h3), dim=1)

        h = self.relu(self.lin1(h))
        h = F.dropout(h, p=0.5, training=self.training)
        h = self.relu(self.lin2(h))
        h = F.dropout(h, p=0.5, training=self.training)
        h = self.lin3(h)

        return h.squeeze()

# %%
# Define the model, optimizer, and loss function

no_node_feature = dataset[0].x.shape[1]
model = Transformer(dim_h=64, node_feature=no_node_feature)
#model = GIN(dim_h=64, node_feature=no_node_feature)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)
criterion = nn.MSELoss()
print(model)

# Define a learning rate scheduler
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=5, factor=0.5, min_lr=1e-5)

# Use GPU if available, otherwise use CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

num_params = sum(p.numel() for p in model.parameters())
print("Number of parameters:", num_params)
# Out:
# Transformer(
#   (conv1): TransformerConv(2, 64, heads=4)
#   (conv2): TransformerConv(256, 64, heads=4)
#   (conv3): TransformerConv(256, 64, heads=4)
#   (lin1): Linear(in_features=768, out_features=128, bias=True)
#   (lin2): Linear(in_features=128, out_features=128, bias=True)
#   (lin3): Linear(in_features=128, out_features=1, bias=True)
#   (relu): ReLU()
# )
# Number of parameters: 644481

# %% [markdown]
# ## Training

# %%
train_losses, test_losses, R2_trainings, R2_tests, best_state_dict = train_model(
    model, train_loader, test_loader, criterion, optimizer, scheduler, device=device, num_epochs=epoch_num)
# Out:
# Epoch [1], LR [0.001], Loss[Train: 1.152, Test: 0.764], R2[Train: -0.051, Test: 0.290]
# Epoch [2], LR [0.001], Loss[Train: 0.324, Test: 0.177], R2[Train: 0.704, Test: 0.836]
# Epoch [3], LR [0.001], Loss[Train: 0.251, Test: 0.327], R2[Train: 0.771, Test: 0.696]
# Epoch [4], LR [0.001], Loss[Train: 0.269, Test: 0.152], R2[Train: 0.754, Test: 0.859]
# Epoch [5], LR [0.001], Loss[Train: 0.212, Test: 0.124], R2[Train: 0.806, Test: 0.884]
# Epoch [6], LR [0.001], Loss[Train: 0.190, Test: 0.172], R2[Train: 0.826, Test: 0.840]
# Epoch [7], LR [0.001], Loss[Train: 0.185, Test: 0.083], R2[Train: 0.831, Test: 0.923]
# Epoch [8], LR [0.001], Loss[Train: 0.153, Test: 0.121], R2[Train: 0.860, Test: 0.887]
# Epoch [9], LR [0.001], Loss[Train: 0.152, Test: 0.162], R2[Train: 0.861, Test: 0.850]
# Epoch [10], LR [0.001], Loss[Train: 0.138, Test: 0.073], R2[Train: 0.874, Test: 0.933]
# Epoch [11], LR [0.001], Loss[Train: 0.129, Test: 0.160], R2[Train: 0.882, Test: 0.851]
# Epoch [12], LR [0.001], Loss[Train: 0.116, Test: 0.079], R2[Train: 0.894, Test: 0.927]
# Epoch [13], LR [0.001], Loss[Train: 0.120, Test: 0.112], R2[Train: 0.890, Test: 0.896]
# Epoch [14], LR [0.001], Loss[Train: 0.124, Test: 0.083], R2[Train: 0.887, Test: 0.923]
# Epoch [15], LR [0.001], Loss[Train: 0.118, Test: 0.129], R2[Train: 0.892, Test: 0.880]
# Epoch [16], LR [0.001], Loss[Train: 0.112, Test: 0.090], R2[Train: 0.897, Test: 0.917]
# Epoch [17], LR [0.001], Loss[Train: 0.109, Test: 0.065], R2[Train: 0.901, Test: 0.939]
# Epoch [18], LR [0.001], Loss[Train: 0.105, Test: 0.306], R2[Train: 0.904, Test: 0.716]
# Epoch [19], LR [0.001], Loss[Train: 0.107, Test: 0.067], R2[Train: 0.902, Test: 0.938]
# Epoch [20], LR [0.001], Loss[Train: 0.105, Test: 0.204], R2[Train: 0.904, Test: 0.810]
# Epoch [21], LR [0.001], Loss[Train: 0.107, Test: 0.081], R2[Train: 0.903, Test: 0.924]
# Epoch [22], LR [0.001], Loss[Train: 0.093, Test: 0.133], R2[Train: 0.915, Test: 0.876]
# Epoch [23], LR [0.001], Loss[Train: 0.093, Test: 0.057], R2[Train: 0.915, Test: 0.947]
# Epoch [24], LR [0.001], Loss[Train: 0.096, Test: 0.084], R2[Train: 0.913, Test: 0.922]
# Epoch [25], LR [0.001], Loss[Train: 0.085, Test: 0.051], R2[Train: 0.922, Test: 0.952]
# Epoch [26], LR [0.001], Loss[Train: 0.080, Test: 0.074], R2[Train: 0.927, Test: 0.931]
# Epoch [27], LR [0.001], Loss[Train: 0.084, Test: 0.076], R2[Train: 0.923, Test: 0.929]
# Epoch [28], LR [0.001], Loss[Train: 0.081, Test: 0.082], R2[Train: 0.926, Test: 0.924]
# Epoch [29], LR [0.001], Loss[Train: 0.085, Test: 0.048], R2[Train: 0.923, Test: 0.955]
# Epoch [30], LR [0.001], Loss[Train: 0.080, Test: 0.113], R2[Train: 0.927, Test: 0.895]
# Epoch [31], LR [0.001], Loss[Train: 0.079, Test: 0.050], R2[Train: 0.928, Test: 0.954]
# Epoch [32], LR [0.001], Loss[Train: 0.072, Test: 0.067], R2[Train: 0.934, Test: 0.938]
# Epoch [33], LR [0.001], Loss[Train: 0.073, Test: 0.047], R2[Train: 0.933, Test: 0.956]
# Epoch [34], LR [0.001], Loss[Train: 0.074, Test: 0.068], R2[Train: 0.932, Test: 0.937]
# Epoch [35], LR [0.001], Loss[Train: 0.077, Test: 0.070], R2[Train: 0.929, Test: 0.935]
# Epoch [36], LR [0.001], Loss[Train: 0.068, Test: 0.079], R2[Train: 0.938, Test: 0.927]
# Epoch [37], LR [0.001], Loss[Train: 0.071, Test: 0.051], R2[Train: 0.935, Test: 0.953]
# Epoch [38], LR [0.001], Loss[Train: 0.068, Test: 0.050], R2[Train: 0.938, Test: 0.954]
# Epoch [39], LR [0.001], Loss[Train: 0.066, Test: 0.089], R2[Train: 0.940, Test: 0.917]
# Epoch [40], LR [0.001], Loss[Train: 0.067, Test: 0.069], R2[Train: 0.939, Test: 0.936]
# Epoch [41], LR [0.001], Loss[Train: 0.069, Test: 0.081], R2[Train: 0.937, Test: 0.925]
# Epoch [42], LR [0.001], Loss[Train: 0.065, Test: 0.062], R2[Train: 0.940, Test: 0.942]
# Epoch [43], LR [0.001], Loss[Train: 0.067, Test: 0.084], R2[Train: 0.939, Test: 0.922]
# Epoch [44], LR [0.001], Loss[Train: 0.061, Test: 0.053], R2[Train: 0.944, Test: 0.951]
# Epoch [45], LR [0.001], Loss[Train: 0.063, Test: 0.170], R2[Train: 0.943, Test: 0.842]
# Epoch [46], LR [0.001], Loss[Train: 0.060, Test: 0.053], R2[Train: 0.946, Test: 0.950]
# Epoch [47], LR [0.001], Loss[Train: 0.062, Test: 0.062], R2[Train: 0.944, Test: 0.942]
# Epoch [48], LR [0.001], Loss[Train: 0.061, Test: 0.043], R2[Train: 0.944, Test: 0.960]
# Epoch [49], LR [0.001], Loss[Train: 0.061, Test: 0.044], R2[Train: 0.944, Test: 0.959]
# Epoch [50], LR [0.001], Loss[Train: 0.058, Test: 0.041], R2[Train: 0.947, Test: 0.962]
# Epoch [51], LR [0.001], Loss[Train: 0.066, Test: 0.043], R2[Train: 0.940, Test: 0.960]
# Epoch [52], LR [0.001], Loss[Train: 0.066, Test: 0.095], R2[Train: 0.940, Test: 0.912]
# Epoch [53], LR [0.001], Loss[Train: 0.060, Test: 0.069], R2[Train: 0.945, Test: 0.936]
# Epoch [54], LR [0.001], Loss[Train: 0.057, Test: 0.071], R2[Train: 0.948, Test: 0.934]
# Epoch [55], LR [0.001], Loss[Train: 0.059, Test: 0.051], R2[Train: 0.946, Test: 0.953]
# Epoch [56], LR [0.001], Loss[Train: 0.056, Test: 0.068], R2[Train: 0.949, Test: 0.937]
# Epoch [57], LR [0.001], Loss[Train: 0.060, Test: 0.047], R2[Train: 0.945, Test: 0.957]
# Epoch [58], LR [0.001], Loss[Train: 0.060, Test: 0.053], R2[Train: 0.945, Test: 0.951]
# Epoch [59], LR [0.001], Loss[Train: 0.056, Test: 0.067], R2[Train: 0.949, Test: 0.937]
# Epoch [60], LR [0.001], Loss[Train: 0.061, Test: 0.055], R2[Train: 0.944, Test: 0.949]
# Epoch [61], LR [0.001], Loss[Train: 0.052, Test: 0.059], R2[Train: 0.953, Test: 0.945]
# Epoch [62], LR [0.001], Loss[Train: 0.056, Test: 0.071], R2[Train: 0.949, Test: 0.934]
# Epoch [63], LR [0.001], Loss[Train: 0.053, Test: 0.051], R2[Train: 0.952, Test: 0.952]
# Epoch [64], LR [0.001], Loss[Train: 0.055, Test: 0.053], R2[Train: 0.950, Test: 0.950]
# Epoch [65], LR [0.001], Loss[Train: 0.056, Test: 0.044], R2[Train: 0.949, Test: 0.959]
# Epoch [66], LR [0.001], Loss[Train: 0.061, Test: 0.061], R2[Train: 0.944, Test: 0.943]
# Epoch [67], LR [0.0005], Loss[Train: 0.054, Test: 0.042], R2[Train: 0.951, Test: 0.961]
# Epoch [68], LR [0.0005], Loss[Train: 0.044, Test: 0.039], R2[Train: 0.960, Test: 0.964]
# Epoch [69], LR [0.0005], Loss[Train: 0.047, Test: 0.039], R2[Train: 0.957, Test: 0.964]
# Epoch [70], LR [0.0005], Loss[Train: 0.044, Test: 0.050], R2[Train: 0.960, Test: 0.953]
# Epoch [71], LR [0.0005], Loss[Train: 0.044, Test: 0.046], R2[Train: 0.960, Test: 0.957]
# Epoch [72], LR [0.0005], Loss[Train: 0.044, Test: 0.045], R2[Train: 0.960, Test: 0.958]
# Epoch [73], LR [0.0005], Loss[Train: 0.044, Test: 0.043], R2[Train: 0.960, Test: 0.960]
# Epoch [74], LR [0.00025], Loss[Train: 0.044, Test: 0.041], R2[Train: 0.960, Test: 0.962]
# Epoch [75], LR [0.00025], Loss[Train: 0.040, Test: 0.041], R2[Train: 0.963, Test: 0.962]
# Epoch [76], LR [0.00025], Loss[Train: 0.039, Test: 0.039], R2[Train: 0.965, Test: 0.964]
# Epoch [77], LR [0.00025], Loss[Train: 0.039, Test: 0.043], R2[Train: 0.964, Test: 0.960]
# Epoch [78], LR [0.00025], Loss[Train: 0.039, Test: 0.043], R2[Train: 0.964, Test: 0.960]
# Epoch [79], LR [0.00025], Loss[Train: 0.038, Test: 0.039], R2[Train: 0.965, Test: 0.964]
# Epoch [80], LR [0.00025], Loss[Train: 0.039, Test: 0.041], R2[Train: 0.965, Test: 0.962]
# Epoch [81], LR [0.00025], Loss[Train: 0.039, Test: 0.038], R2[Train: 0.965, Test: 0.965]
# Epoch [82], LR [0.00025], Loss[Train: 0.039, Test: 0.040], R2[Train: 0.965, Test: 0.963]
# Epoch [83], LR [0.00025], Loss[Train: 0.039, Test: 0.042], R2[Train: 0.965, Test: 0.961]
# Epoch [84], LR [0.00025], Loss[Train: 0.041, Test: 0.038], R2[Train: 0.963, Test: 0.964]
# Epoch [85], LR [0.000125], Loss[Train: 0.040, Test: 0.042], R2[Train: 0.964, Test: 0.961]
# Epoch [86], LR [0.000125], Loss[Train: 0.037, Test: 0.040], R2[Train: 0.966, Test: 0.963]
# Epoch [87], LR [0.000125], Loss[Train: 0.037, Test: 0.038], R2[Train: 0.966, Test: 0.965]
# Epoch [88], LR [0.000125], Loss[Train: 0.036, Test: 0.039], R2[Train: 0.967, Test: 0.964]
# Epoch [89], LR [0.000125], Loss[Train: 0.036, Test: 0.037], R2[Train: 0.967, Test: 0.965]
# Epoch [90], LR [0.000125], Loss[Train: 0.037, Test: 0.039], R2[Train: 0.966, Test: 0.964]
# Epoch [91], LR [0.000125], Loss[Train: 0.037, Test: 0.038], R2[Train: 0.967, Test: 0.965]
# Epoch [92], LR [0.000125], Loss[Train: 0.037, Test: 0.042], R2[Train: 0.966, Test: 0.961]
# Epoch [93], LR [0.000125], Loss[Train: 0.036, Test: 0.038], R2[Train: 0.967, Test: 0.964]
# Epoch [94], LR [0.000125], Loss[Train: 0.036, Test: 0.037], R2[Train: 0.967, Test: 0.966]
# Epoch [95], LR [6.25e-05], Loss[Train: 0.036, Test: 0.037], R2[Train: 0.967, Test: 0.966]
# Epoch [96], LR [6.25e-05], Loss[Train: 0.035, Test: 0.037], R2[Train: 0.968, Test: 0.966]
# Epoch [97], LR [6.25e-05], Loss[Train: 0.035, Test: 0.038], R2[Train: 0.968, Test: 0.965]
# Epoch [98], LR [6.25e-05], Loss[Train: 0.035, Test: 0.040], R2[Train: 0.968, Test: 0.962]
# Epoch [99], LR [6.25e-05], Loss[Train: 0.035, Test: 0.040], R2[Train: 0.968, Test: 0.963]
# Epoch [100], LR [6.25e-05], Loss[Train: 0.035, Test: 0.036], R2[Train: 0.968, Test: 0.966]
# Epoch [101], LR [6.25e-05], Loss[Train: 0.035, Test: 0.037], R2[Train: 0.968, Test: 0.965]
# Epoch [102], LR [6.25e-05], Loss[Train: 0.035, Test: 0.036], R2[Train: 0.968, Test: 0.966]
# Epoch [103], LR [3.125e-05], Loss[Train: 0.035, Test: 0.040], R2[Train: 0.968, Test: 0.963]
# Epoch [104], LR [3.125e-05], Loss[Train: 0.034, Test: 0.037], R2[Train: 0.969, Test: 0.965]
# Epoch [105], LR [3.125e-05], Loss[Train: 0.034, Test: 0.037], R2[Train: 0.969, Test: 0.966]
# Epoch [106], LR [3.125e-05], Loss[Train: 0.034, Test: 0.036], R2[Train: 0.969, Test: 0.967]
# Epoch [107], LR [3.125e-05], Loss[Train: 0.034, Test: 0.037], R2[Train: 0.969, Test: 0.966]
# Epoch [108], LR [3.125e-05], Loss[Train: 0.034, Test: 0.037], R2[Train: 0.969, Test: 0.966]
# Epoch [109], LR [3.125e-05], Loss[Train: 0.034, Test: 0.036], R2[Train: 0.969, Test: 0.966]
# Epoch [110], LR [3.125e-05], Loss[Train: 0.034, Test: 0.036], R2[Train: 0.969, Test: 0.966]
# Epoch [111], LR [3.125e-05], Loss[Train: 0.034, Test: 0.037], R2[Train: 0.969, Test: 0.965]
# Epoch [112], LR [3.125e-05], Loss[Train: 0.034, Test: 0.036], R2[Train: 0.969, Test: 0.966]
# Epoch [113], LR [3.125e-05], Loss[Train: 0.034, Test: 0.036], R2[Train: 0.969, Test: 0.966]
# Epoch [114], LR [3.125e-05], Loss[Train: 0.034, Test: 0.036], R2[Train: 0.969, Test: 0.966]
# Epoch [115], LR [3.125e-05], Loss[Train: 0.034, Test: 0.037], R2[Train: 0.969, Test: 0.966]
# Epoch [116], LR [3.125e-05], Loss[Train: 0.034, Test: 0.036], R2[Train: 0.969, Test: 0.967]
# Epoch [117], LR [1.5625e-05], Loss[Train: 0.034, Test: 0.037], R2[Train: 0.969, Test: 0.966]
# Epoch [118], LR [1.5625e-05], Loss[Train: 0.034, Test: 0.036], R2[Train: 0.969, Test: 0.966]
# Epoch [119], LR [1.5625e-05], Loss[Train: 0.034, Test: 0.038], R2[Train: 0.969, Test: 0.965]
# Epoch [120], LR [1.5625e-05], Loss[Train: 0.034, Test: 0.036], R2[Train: 0.969, Test: 0.967]
# Epoch [121], LR [1.5625e-05], Loss[Train: 0.033, Test: 0.038], R2[Train: 0.969, Test: 0.965]
# Epoch [122], LR [1.5625e-05], Loss[Train: 0.034, Test: 0.036], R2[Train: 0.969, Test: 0.966]
# Epoch [123], LR [1.5625e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.969, Test: 0.966]
# Epoch [124], LR [1.5625e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [125], LR [1.5625e-05], Loss[Train: 0.034, Test: 0.036], R2[Train: 0.969, Test: 0.967]
# Epoch [126], LR [1.5625e-05], Loss[Train: 0.033, Test: 0.037], R2[Train: 0.970, Test: 0.966]
# Epoch [127], LR [1.5625e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.969, Test: 0.966]
# Epoch [128], LR [1.5625e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [129], LR [1.5625e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [130], LR [1.5625e-05], Loss[Train: 0.033, Test: 0.037], R2[Train: 0.969, Test: 0.966]
# Epoch [131], LR [1.5625e-05], Loss[Train: 0.033, Test: 0.037], R2[Train: 0.970, Test: 0.966]
# Epoch [132], LR [1e-05], Loss[Train: 0.034, Test: 0.036], R2[Train: 0.969, Test: 0.967]
# Epoch [133], LR [1e-05], Loss[Train: 0.033, Test: 0.037], R2[Train: 0.970, Test: 0.966]
# Epoch [134], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [135], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [136], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [137], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [138], LR [1e-05], Loss[Train: 0.033, Test: 0.037], R2[Train: 0.970, Test: 0.966]
# Epoch [139], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [140], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [141], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [142], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [143], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [144], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [145], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [146], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [147], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [148], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [149], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [150], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [151], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [152], LR [1e-05], Loss[Train: 0.033, Test: 0.037], R2[Train: 0.970, Test: 0.965]
# Epoch [153], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [154], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [155], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [156], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [157], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [158], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [159], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [160], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [161], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [162], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [163], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [164], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [165], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [166], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [167], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [168], LR [1e-05], Loss[Train: 0.033, Test: 0.037], R2[Train: 0.970, Test: 0.966]
# Epoch [169], LR [1e-05], Loss[Train: 0.033, Test: 0.037], R2[Train: 0.970, Test: 0.966]
# Epoch [170], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [171], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [172], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [173], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [174], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [175], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [176], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [177], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [178], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [179], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [180], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [181], LR [1e-05], Loss[Train: 0.033, Test: 0.037], R2[Train: 0.970, Test: 0.966]
# Epoch [182], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [183], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [184], LR [1e-05], Loss[Train: 0.033, Test: 0.037], R2[Train: 0.970, Test: 0.966]
# Epoch [185], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [186], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [187], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [188], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [189], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [190], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [191], LR [1e-05], Loss[Train: 0.033, Test: 0.037], R2[Train: 0.970, Test: 0.966]
# Epoch [192], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [193], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [194], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [195], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [196], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [197], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [198], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.966]
# Epoch [199], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Epoch [200], LR [1e-05], Loss[Train: 0.033, Test: 0.036], R2[Train: 0.970, Test: 0.967]
# Final Test Loss: 0.0357

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5,5), dpi=400) 

plt.rcParams['font.serif'] = ['Times New Roman']
plt.rcParams['font.size'] = 12

plt.plot(np.array(train_losses), label='Train')
plt.plot(np.array(test_losses), label='Validation')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.yscale("log") 
plt.xlim(0,epoch_num)
plt.tight_layout()

# %% [markdown]
# # Save model

# %%
best_model_path = f'/kaggle/working/epoch_{args.epoch_num}.pt'  
torch.save(best_state_dict, best_model_path)

# %% [markdown]
# ## Training and Validation data

# %%
R2 = evaluate_model(model, train_loader, device, args.cover_interval, overlap, args.save_model_dir)
# Out:
# Test R2 for E: 0.9696429065343096

# %%
R2 = evaluate_model(model, test_loader, device, args.cover_interval, overlap, args.save_model_dir)
# Out:
# Test R2 for E: 0.9668250559564536

# %% [markdown]
# ## Testing data

# %%
R2 = evaluate_model(model, valid_loader, device, args.cover_interval, overlap, args.save_model_dir)
# Out:
# Test R2 for E: 0.9674577616702973
