# %%
# Run using accelerator GPU T4x2 
# change the path below to run
# %cd /kaggle/working
# !cp -r /kaggle/input/datasets/letplay/graph-nn/gnn-model /kaggle/working/
# %cd /kaggle/working/gnn-model
# %pip install torch_geometric
# !python final_model_local.py --epoch_num 200 --data_dir /kaggle/input/datasets/letplay/graph-nn/gnn-model --save_model_dir /kaggle/working/saved_model
# Out:
# /kaggle/working
# /kaggle/working/gnn-model
# ...
# Number of duplicate graphs with same coordinates, edges, and E: 0
# Graphs are undirected (before conversion): False
# Graphs are undirected (after conversion): True
# Using CUDA GPU
# Transformer(
#   (conv1): TransformerConv(2, 64, heads=4)
#   (conv2): TransformerConv(256, 64, heads=4)
#   (conv3): TransformerConv(256, 64, heads=4)
#   (lin1): Linear(in_features=768, out_features=128, bias=True)
#   (lin2): Linear(in_features=128, out_features=128, bias=True)
#   (lin3): Linear(in_features=128, out_features=1, bias=True)
#   (relu): ReLU()
# )
# Device: cuda
# Number of parameters: 644481
# Epoch [1], LR [0.001], Loss[Train: 0.484, Valid: 0.327], R2[Train: 0.557, Valid: 0.697]
# Epoch [2], LR [0.001], Loss[Train: 0.324, Valid: 0.326], R2[Train: 0.703, Valid: 0.698]
# Epoch [3], LR [0.001], Loss[Train: 0.336, Valid: 0.271], R2[Train: 0.693, Valid: 0.749]
# ...
