# %%
# %cd /kaggle/working
# !cp -r /kaggle/input/datasets/your-data-path /kaggle/working/
# %cd /kaggle/working/gnn-model
# %pip install torch_geometric -q
# Out:
# /kaggle/working
# /kaggle/working/gnn-model
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

from torch_geometric.data import Data

from utils.data_processing import *
from utils.architecture import GIN, Transformer
from utils.train_model import train_model
from utils.evaluate_model import *

# %%
class Args:
    data_dir = "/kaggle/input/datasets/your-data-path"  # folder containing Hexagonal, Kagome, Demi-A, Demi-B, Demi-C
    batch_num = 32
    epoch_num = 200
    cover_interval = 20
    overlap = 0.3
    save_model_dir = "/kaggle/working/saved_model"
    model = "transformer"  # "transformer" or "gin"

args = Args()
os.makedirs(args.save_model_dir, exist_ok=True)

folder_list = ["Hexagonal", "Kagome", "Demi-A", "Demi-B", "Demi-C"]
batch_size = args.batch_num
epoch_num = args.epoch_num
learning_rate = 0.001
overlap = args.overlap

# %% [markdown]
# ## 1. Load dataset

# %%
def load_inp_data(file_path, label):
    nodes, edges = [], []

    with open(file_path, "r") as file:
        lines = file.readlines()

    node_section = False
    element_section = False

    for line in lines:
        line = line.strip()

        if "*Node" in line:
            node_section = True
            element_section = False
            continue

        if "*Element" in line:
            node_section = False
            element_section = True
            continue

        if "*Nset" in line or "*Elset" in line:
            node_section = False
            element_section = False
            continue

        if node_section:
            parts = line.split(",")
            if len(parts) >= 3:
                try:
                    x = float(parts[1].strip())
                    y = float(parts[2].strip())
                    nodes.append([x, y])
                except ValueError:
                    continue

        if element_section:
            parts = line.split(",")
            if (len(parts) >= 3 and parts[0].strip().isdigit() and parts[1].strip().isdigit() and parts[2].strip().isdigit()):
                start = int(parts[1].strip()) - 1
                end = int(parts[2].strip()) - 1

                if start == end:
                    continue

                if start < len(nodes) and end < len(nodes):
                    edges.append([start, end])
                else:
                    print(f"Skipping invalid edge ({start + 1}, {end + 1}) in {file_path}")

    node_tensor = torch.tensor(nodes, dtype=torch.float)
    edge_tensor = (
        torch.tensor(edges, dtype=torch.long).t().contiguous()
        if edges
        else torch.empty((2, 0), dtype=torch.long)
    )

    return Data(x=node_tensor, edge_index=edge_tensor, E=np.float64(label * 200.00))


def load_dataset(data_dir, folder_list):
    dataset = []

    for folder in folder_list:
        results_path = os.path.join(data_dir, folder, "Results.txt")
        inp_folder = os.path.join(data_dir, folder, "inp_files")

        if not os.path.exists(results_path):
            raise FileNotFoundError(f"Missing Results.txt: {results_path}")

        if not os.path.isdir(inp_folder):
            raise FileNotFoundError(f"Missing inp_files folder: {inp_folder}")

        file_labels = {}
        with open(results_path, "r") as file:
            for line in file:
                if line.strip() == "" or "E/Es" in line:
                    continue
                try:
                    file_name, label = line.strip().split(", ")
                    filename = file_name.strip().split(".")[0]
                    file_labels[filename] = float(label)
                except ValueError:
                    print(f"[{folder}] Skipping invalid line: {line.strip()}")

        for file, label in file_labels.items():
            file_path = os.path.join(inp_folder, f"{file}.inp")
            if os.path.exists(file_path):
                dataset.append(load_inp_data(file_path, label))
            else:
                print(f"[{folder}] Missing file: {file_path}")

    if len(dataset) == 0:
        raise RuntimeError("No graph data was loaded. Check --data_dir and folder names.")

    return dataset

# %%
dataset = load_dataset(args.data_dir, folder_list)
check_duplicate_graphs(dataset)
# Out:
# Number of duplicate graphs with same coordinates, edges, and E: 0
# []

# %% [markdown]
# ## Make graphs undirected

# %%
all_undirected_before = all(is_undirected(data) for data in dataset)
print(f"Graphs are undirected (before conversion): {all_undirected_before}")

dataset = [make_undirected(data) for data in dataset]

all_undirected_after = all(is_undirected(data) for data in dataset)
print(f"Graphs are undirected (after conversion): {all_undirected_after}")
# Out:
# Graphs are undirected (before conversion): False
# Graphs are undirected (after conversion): True

# %% [markdown]
# ## Split, normalize, build loaders

# %%
dataset_size = len(dataset)
train_size = int(0.80 * dataset_size)
valid_size = int(0.10 * dataset_size)
test_size = dataset_size - train_size - valid_size

train_set, valid_set, test_set = random_split(
    dataset, [train_size, valid_size, test_size],
    generator=torch.Generator().manual_seed(42)
)

# Extract lists to normalize safely using Training criteria
train_list, valid_list, test_list = list(train_set), list(valid_set), list(test_set)
train_list, valid_list, test_list = normalize_planar_info(train_list, valid_list, test_list)

train_loader = DataLoader(train_list, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_list, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_list, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## Dataset distribution

# %%
def plot_dataset(dataset, output_dir):
    E_vals = [data.E for data in dataset]

    plt.figure(figsize=(5, 5), dpi=150)
    plt.rcParams["font.serif"] = ["Times New Roman"]
    plt.rcParams["font.size"] = 13

    labels = ["Hexagonal", "Kagome", "Demi-A", "Demi-B", "Demi-C"]
    markers = ["o", "s", "^", "D", "x"]
    colors = ["blue", "green", "red", "orange", "purple"]

    size = 4951
    for i in range(5):
        start = i * size
        end = min((i + 1) * size, len(E_vals))
        if start >= len(E_vals):
            break
        x = range(start, end)
        y = E_vals[start:end]
        plt.plot(x, y, linestyle="none", marker=markers[i], color=colors[i], markersize=3, label=labels[i], alpha=0.4)

    plt.ylabel(r"Elastic Modulus $E$ (GPa)")
    plt.xlabel("Samples")
    plt.xlim(right=25000)
    plt.ylim(top=3.5)
    plt.legend()
    plt.tight_layout()

    os.makedirs(output_dir, exist_ok=True)
    plt.savefig(os.path.join(output_dir, "dataset_distribution.png"))
    plt.show()


plot_dataset(dataset, args.save_model_dir)

# %% [markdown]
# ## 2. Build model, optimizer, scheduler

# %%
no_node_feature = dataset[0].x.shape[1]

if args.model == "transformer":
    model = Transformer(dim_h=64, node_feature=no_node_feature)
else:
    model = GIN(dim_h=64, node_feature=no_node_feature)

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)
criterion = nn.MSELoss()
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", patience=5, factor=0.5, min_lr=1e-5)

if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Using Apple GPU (MPS)")
elif torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using CUDA GPU")
else:
    device = torch.device("cpu")
    print("Using CPU")

model.to(device)
print(model)
print("Device:", device)

num_params = sum(p.numel() for p in model.parameters())
print("Number of parameters:", num_params)
# Out:
# Using CUDA GPU
# Transformer(
#   (conv1): TransformerConv(2, 64, heads=4)
#   (conv2): TransformerConv(256, 64, heads=4)
#   (conv3): TransformerConv(256, 64, heads=4)
#   (lin1): Linear(in_features=768, out_features=128, bias=True)
#   (lin2): Linear(in_features=128, out_features=128, bias=True)
#   (lin3): Linear(in_features=128, out_features=1, bias=True)
#   (relu): ReLU()
# )
# Device: cuda
# Number of parameters: 644481

# %% [markdown]
# ## 3. Training

# %%
train_losses, valid_losses, R2_trainings, R2_valids, best_state_dict = train_model(
    model, train_loader, valid_loader, criterion,
    optimizer, scheduler, device=device, num_epochs=epoch_num,
)
# Out:
# Epoch [1], LR [0.001], Loss[Train: 0.451, Valid: 0.298], R2[Train: 0.588, Valid: 0.724]
# Epoch [2], LR [0.001], Loss[Train: 0.331, Valid: 0.443], R2[Train: 0.697, Valid: 0.591]
# Epoch [3], LR [0.001], Loss[Train: 0.316, Valid: 0.306], R2[Train: 0.711, Valid: 0.717]
# Epoch [4], LR [0.001], Loss[Train: 0.313, Valid: 0.279], R2[Train: 0.713, Valid: 0.742]
# Epoch [5], LR [0.001], Loss[Train: 0.291, Valid: 0.274], R2[Train: 0.734, Valid: 0.746]
# Epoch [6], LR [0.001], Loss[Train: 0.282, Valid: 0.286], R2[Train: 0.742, Valid: 0.735]
# Epoch [7], LR [0.001], Loss[Train: 0.279, Valid: 0.291], R2[Train: 0.745, Valid: 0.731]
# Epoch [8], LR [0.001], Loss[Train: 0.273, Valid: 0.265], R2[Train: 0.750, Valid: 0.755]
# Epoch [9], LR [0.001], Loss[Train: 0.268, Valid: 0.274], R2[Train: 0.755, Valid: 0.746]
# Epoch [10], LR [0.001], Loss[Train: 0.270, Valid: 0.267], R2[Train: 0.753, Valid: 0.753]
# Epoch [11], LR [0.001], Loss[Train: 0.276, Valid: 0.265], R2[Train: 0.747, Valid: 0.755]
# Epoch [12], LR [0.001], Loss[Train: 0.267, Valid: 0.266], R2[Train: 0.756, Valid: 0.754]
# Epoch [13], LR [0.001], Loss[Train: 0.265, Valid: 0.273], R2[Train: 0.757, Valid: 0.747]
# Epoch [14], LR [0.001], Loss[Train: 0.266, Valid: 0.266], R2[Train: 0.757, Valid: 0.754]
# Epoch [15], LR [0.001], Loss[Train: 0.265, Valid: 0.265], R2[Train: 0.758, Valid: 0.755]
# Epoch [16], LR [0.001], Loss[Train: 0.265, Valid: 0.264], R2[Train: 0.758, Valid: 0.756]
# Epoch [17], LR [0.001], Loss[Train: 0.266, Valid: 0.275], R2[Train: 0.756, Valid: 0.746]
# Epoch [18], LR [0.001], Loss[Train: 0.266, Valid: 0.271], R2[Train: 0.757, Valid: 0.750]
# Epoch [19], LR [0.001], Loss[Train: 0.264, Valid: 0.282], R2[Train: 0.758, Valid: 0.740]
# Epoch [20], LR [0.001], Loss[Train: 0.264, Valid: 0.265], R2[Train: 0.758, Valid: 0.755]
# Epoch [21], LR [0.001], Loss[Train: 0.264, Valid: 0.264], R2[Train: 0.759, Valid: 0.756]
# Epoch [22], LR [0.0005], Loss[Train: 0.261, Valid: 0.264], R2[Train: 0.761, Valid: 0.756]
# Epoch [23], LR [0.0005], Loss[Train: 0.259, Valid: 0.266], R2[Train: 0.763, Valid: 0.754]
# Epoch [24], LR [0.0005], Loss[Train: 0.258, Valid: 0.266], R2[Train: 0.764, Valid: 0.754]
# Epoch [25], LR [0.0005], Loss[Train: 0.258, Valid: 0.260], R2[Train: 0.764, Valid: 0.759]
# Epoch [26], LR [0.0005], Loss[Train: 0.258, Valid: 0.259], R2[Train: 0.764, Valid: 0.761]
# Epoch [27], LR [0.0005], Loss[Train: 0.258, Valid: 0.259], R2[Train: 0.764, Valid: 0.760]
# Epoch [28], LR [0.0005], Loss[Train: 0.257, Valid: 0.265], R2[Train: 0.765, Valid: 0.755]
# Epoch [29], LR [0.0005], Loss[Train: 0.258, Valid: 0.259], R2[Train: 0.764, Valid: 0.760]
# Epoch [30], LR [0.0005], Loss[Train: 0.256, Valid: 0.262], R2[Train: 0.765, Valid: 0.758]
# Epoch [31], LR [0.0005], Loss[Train: 0.253, Valid: 0.251], R2[Train: 0.769, Valid: 0.768]
# Epoch [32], LR [0.0005], Loss[Train: 0.251, Valid: 0.254], R2[Train: 0.770, Valid: 0.765]
# Epoch [33], LR [0.0005], Loss[Train: 0.243, Valid: 0.223], R2[Train: 0.778, Valid: 0.794]
# Epoch [34], LR [0.0005], Loss[Train: 0.223, Valid: 0.231], R2[Train: 0.796, Valid: 0.786]
# Epoch [35], LR [0.0005], Loss[Train: 0.178, Valid: 0.142], R2[Train: 0.837, Valid: 0.869]
# Epoch [36], LR [0.0005], Loss[Train: 0.143, Valid: 0.119], R2[Train: 0.869, Valid: 0.890]
# Epoch [37], LR [0.0005], Loss[Train: 0.117, Valid: 0.081], R2[Train: 0.893, Valid: 0.925]
# Epoch [38], LR [0.0005], Loss[Train: 0.123, Valid: 0.107], R2[Train: 0.887, Valid: 0.902]
# Epoch [39], LR [0.0005], Loss[Train: 0.134, Valid: 0.123], R2[Train: 0.878, Valid: 0.886]
# Epoch [40], LR [0.0005], Loss[Train: 0.104, Valid: 0.132], R2[Train: 0.905, Valid: 0.878]
# Epoch [41], LR [0.0005], Loss[Train: 0.108, Valid: 0.057], R2[Train: 0.902, Valid: 0.947]
# Epoch [42], LR [0.0005], Loss[Train: 0.103, Valid: 0.076], R2[Train: 0.906, Valid: 0.929]
# Epoch [43], LR [0.0005], Loss[Train: 0.093, Valid: 0.052], R2[Train: 0.915, Valid: 0.952]
# Epoch [44], LR [0.0005], Loss[Train: 0.102, Valid: 0.071], R2[Train: 0.907, Valid: 0.934]
# Epoch [45], LR [0.0005], Loss[Train: 0.081, Valid: 0.061], R2[Train: 0.926, Valid: 0.944]
# Epoch [46], LR [0.0005], Loss[Train: 0.082, Valid: 0.180], R2[Train: 0.925, Valid: 0.833]
# Epoch [47], LR [0.0005], Loss[Train: 0.095, Valid: 0.042], R2[Train: 0.913, Valid: 0.961]
# Epoch [48], LR [0.0005], Loss[Train: 0.100, Valid: 0.079], R2[Train: 0.909, Valid: 0.927]
# Epoch [49], LR [0.0005], Loss[Train: 0.076, Valid: 0.056], R2[Train: 0.930, Valid: 0.948]
# Epoch [50], LR [0.0005], Loss[Train: 0.100, Valid: 0.226], R2[Train: 0.909, Valid: 0.791]
# Epoch [51], LR [0.0005], Loss[Train: 0.096, Valid: 0.067], R2[Train: 0.912, Valid: 0.938]
# Epoch [52], LR [0.0005], Loss[Train: 0.071, Valid: 0.159], R2[Train: 0.935, Valid: 0.853]
# Epoch [53], LR [0.00025], Loss[Train: 0.083, Valid: 0.076], R2[Train: 0.924, Valid: 0.929]
# Epoch [54], LR [0.00025], Loss[Train: 0.058, Valid: 0.048], R2[Train: 0.947, Valid: 0.956]
# Epoch [55], LR [0.00025], Loss[Train: 0.053, Valid: 0.051], R2[Train: 0.952, Valid: 0.953]
# Epoch [56], LR [0.00025], Loss[Train: 0.058, Valid: 0.050], R2[Train: 0.947, Valid: 0.953]
# Epoch [57], LR [0.00025], Loss[Train: 0.054, Valid: 0.131], R2[Train: 0.950, Valid: 0.879]
# Epoch [58], LR [0.00025], Loss[Train: 0.062, Valid: 0.052], R2[Train: 0.943, Valid: 0.952]
# Epoch [59], LR [0.000125], Loss[Train: 0.058, Valid: 0.098], R2[Train: 0.947, Valid: 0.910]
# Epoch [60], LR [0.000125], Loss[Train: 0.045, Valid: 0.046], R2[Train: 0.959, Valid: 0.958]
# Epoch [61], LR [0.000125], Loss[Train: 0.043, Valid: 0.037], R2[Train: 0.961, Valid: 0.966]
# Epoch [62], LR [0.000125], Loss[Train: 0.046, Valid: 0.044], R2[Train: 0.958, Valid: 0.960]
# Epoch [63], LR [0.000125], Loss[Train: 0.042, Valid: 0.040], R2[Train: 0.962, Valid: 0.963]
# Epoch [64], LR [0.000125], Loss[Train: 0.042, Valid: 0.037], R2[Train: 0.961, Valid: 0.966]
# Epoch [65], LR [0.000125], Loss[Train: 0.043, Valid: 0.035], R2[Train: 0.961, Valid: 0.967]
# Epoch [66], LR [0.000125], Loss[Train: 0.042, Valid: 0.049], R2[Train: 0.962, Valid: 0.954]
# Epoch [67], LR [0.000125], Loss[Train: 0.042, Valid: 0.039], R2[Train: 0.962, Valid: 0.964]
# Epoch [68], LR [0.000125], Loss[Train: 0.044, Valid: 0.059], R2[Train: 0.960, Valid: 0.946]
# Epoch [69], LR [0.000125], Loss[Train: 0.044, Valid: 0.036], R2[Train: 0.960, Valid: 0.966]
# Epoch [70], LR [0.000125], Loss[Train: 0.041, Valid: 0.040], R2[Train: 0.962, Valid: 0.963]
# Epoch [71], LR [6.25e-05], Loss[Train: 0.042, Valid: 0.043], R2[Train: 0.961, Valid: 0.960]
# Epoch [72], LR [6.25e-05], Loss[Train: 0.037, Valid: 0.036], R2[Train: 0.967, Valid: 0.966]
# Epoch [73], LR [6.25e-05], Loss[Train: 0.037, Valid: 0.055], R2[Train: 0.966, Valid: 0.949]
# Epoch [74], LR [6.25e-05], Loss[Train: 0.038, Valid: 0.034], R2[Train: 0.965, Valid: 0.969]
# Epoch [75], LR [6.25e-05], Loss[Train: 0.037, Valid: 0.035], R2[Train: 0.966, Valid: 0.968]
# Epoch [76], LR [6.25e-05], Loss[Train: 0.037, Valid: 0.034], R2[Train: 0.966, Valid: 0.969]
# Epoch [77], LR [6.25e-05], Loss[Train: 0.038, Valid: 0.039], R2[Train: 0.966, Valid: 0.964]
# Epoch [78], LR [6.25e-05], Loss[Train: 0.037, Valid: 0.034], R2[Train: 0.966, Valid: 0.968]
# Epoch [79], LR [6.25e-05], Loss[Train: 0.036, Valid: 0.036], R2[Train: 0.967, Valid: 0.967]
# Epoch [80], LR [6.25e-05], Loss[Train: 0.036, Valid: 0.033], R2[Train: 0.967, Valid: 0.969]
# Epoch [81], LR [6.25e-05], Loss[Train: 0.035, Valid: 0.034], R2[Train: 0.968, Valid: 0.969]
# Epoch [82], LR [6.25e-05], Loss[Train: 0.035, Valid: 0.038], R2[Train: 0.968, Valid: 0.964]
# Epoch [83], LR [6.25e-05], Loss[Train: 0.037, Valid: 0.041], R2[Train: 0.966, Valid: 0.962]
# Epoch [84], LR [6.25e-05], Loss[Train: 0.035, Valid: 0.034], R2[Train: 0.968, Valid: 0.969]
# Epoch [85], LR [6.25e-05], Loss[Train: 0.037, Valid: 0.037], R2[Train: 0.966, Valid: 0.965]
# Epoch [86], LR [3.125e-05], Loss[Train: 0.035, Valid: 0.035], R2[Train: 0.968, Valid: 0.968]
# Epoch [87], LR [3.125e-05], Loss[Train: 0.034, Valid: 0.033], R2[Train: 0.969, Valid: 0.970]
# Epoch [88], LR [3.125e-05], Loss[Train: 0.033, Valid: 0.038], R2[Train: 0.969, Valid: 0.965]
# Epoch [89], LR [3.125e-05], Loss[Train: 0.033, Valid: 0.032], R2[Train: 0.969, Valid: 0.970]
# Epoch [90], LR [3.125e-05], Loss[Train: 0.033, Valid: 0.041], R2[Train: 0.970, Valid: 0.963]
# Epoch [91], LR [3.125e-05], Loss[Train: 0.033, Valid: 0.033], R2[Train: 0.970, Valid: 0.970]
# Epoch [92], LR [3.125e-05], Loss[Train: 0.034, Valid: 0.033], R2[Train: 0.969, Valid: 0.970]
# Epoch [93], LR [3.125e-05], Loss[Train: 0.033, Valid: 0.036], R2[Train: 0.970, Valid: 0.967]
# Epoch [94], LR [3.125e-05], Loss[Train: 0.033, Valid: 0.033], R2[Train: 0.970, Valid: 0.970]
# Epoch [95], LR [3.125e-05], Loss[Train: 0.034, Valid: 0.032], R2[Train: 0.969, Valid: 0.970]
# Epoch [96], LR [3.125e-05], Loss[Train: 0.033, Valid: 0.036], R2[Train: 0.970, Valid: 0.967]
# Epoch [97], LR [3.125e-05], Loss[Train: 0.033, Valid: 0.032], R2[Train: 0.970, Valid: 0.970]
# Epoch [98], LR [3.125e-05], Loss[Train: 0.033, Valid: 0.038], R2[Train: 0.969, Valid: 0.965]
# Epoch [99], LR [3.125e-05], Loss[Train: 0.033, Valid: 0.032], R2[Train: 0.970, Valid: 0.971]
# Epoch [100], LR [3.125e-05], Loss[Train: 0.032, Valid: 0.042], R2[Train: 0.971, Valid: 0.961]
# Epoch [101], LR [3.125e-05], Loss[Train: 0.033, Valid: 0.034], R2[Train: 0.970, Valid: 0.969]
# Epoch [102], LR [3.125e-05], Loss[Train: 0.034, Valid: 0.032], R2[Train: 0.969, Valid: 0.970]
# Epoch [103], LR [3.125e-05], Loss[Train: 0.033, Valid: 0.042], R2[Train: 0.970, Valid: 0.961]
# Epoch [104], LR [3.125e-05], Loss[Train: 0.033, Valid: 0.039], R2[Train: 0.970, Valid: 0.964]
# Epoch [105], LR [1.5625e-05], Loss[Train: 0.033, Valid: 0.034], R2[Train: 0.970, Valid: 0.969]
# Epoch [106], LR [1.5625e-05], Loss[Train: 0.032, Valid: 0.032], R2[Train: 0.971, Valid: 0.970]
# Epoch [107], LR [1.5625e-05], Loss[Train: 0.032, Valid: 0.032], R2[Train: 0.971, Valid: 0.971]
# Epoch [108], LR [1.5625e-05], Loss[Train: 0.032, Valid: 0.032], R2[Train: 0.971, Valid: 0.971]
# Epoch [109], LR [1.5625e-05], Loss[Train: 0.032, Valid: 0.032], R2[Train: 0.971, Valid: 0.970]
# Epoch [110], LR [1.5625e-05], Loss[Train: 0.031, Valid: 0.032], R2[Train: 0.971, Valid: 0.970]
# Epoch [111], LR [1.5625e-05], Loss[Train: 0.032, Valid: 0.032], R2[Train: 0.971, Valid: 0.970]
# Epoch [112], LR [1.5625e-05], Loss[Train: 0.032, Valid: 0.035], R2[Train: 0.971, Valid: 0.968]
# Epoch [113], LR [1e-05], Loss[Train: 0.031, Valid: 0.032], R2[Train: 0.971, Valid: 0.970]
# Epoch [114], LR [1e-05], Loss[Train: 0.031, Valid: 0.032], R2[Train: 0.972, Valid: 0.971]
# Epoch [115], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [116], LR [1e-05], Loss[Train: 0.031, Valid: 0.034], R2[Train: 0.972, Valid: 0.968]
# Epoch [117], LR [1e-05], Loss[Train: 0.031, Valid: 0.032], R2[Train: 0.972, Valid: 0.970]
# Epoch [118], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [119], LR [1e-05], Loss[Train: 0.031, Valid: 0.033], R2[Train: 0.972, Valid: 0.970]
# Epoch [120], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [121], LR [1e-05], Loss[Train: 0.031, Valid: 0.032], R2[Train: 0.971, Valid: 0.971]
# Epoch [122], LR [1e-05], Loss[Train: 0.031, Valid: 0.032], R2[Train: 0.972, Valid: 0.970]
# Epoch [123], LR [1e-05], Loss[Train: 0.031, Valid: 0.032], R2[Train: 0.972, Valid: 0.971]
# Epoch [124], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [125], LR [1e-05], Loss[Train: 0.031, Valid: 0.033], R2[Train: 0.971, Valid: 0.970]
# Epoch [126], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [127], LR [1e-05], Loss[Train: 0.031, Valid: 0.032], R2[Train: 0.972, Valid: 0.970]
# Epoch [128], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [129], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [130], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [131], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [132], LR [1e-05], Loss[Train: 0.031, Valid: 0.033], R2[Train: 0.972, Valid: 0.969]
# Epoch [133], LR [1e-05], Loss[Train: 0.031, Valid: 0.032], R2[Train: 0.972, Valid: 0.971]
# Epoch [134], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [135], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [136], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [137], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [138], LR [1e-05], Loss[Train: 0.031, Valid: 0.032], R2[Train: 0.972, Valid: 0.971]
# Epoch [139], LR [1e-05], Loss[Train: 0.031, Valid: 0.034], R2[Train: 0.972, Valid: 0.969]
# Epoch [140], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [141], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [142], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [143], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [144], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [145], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [146], LR [1e-05], Loss[Train: 0.031, Valid: 0.033], R2[Train: 0.972, Valid: 0.970]
# Epoch [147], LR [1e-05], Loss[Train: 0.031, Valid: 0.032], R2[Train: 0.972, Valid: 0.971]
# Epoch [148], LR [1e-05], Loss[Train: 0.031, Valid: 0.032], R2[Train: 0.972, Valid: 0.970]
# Epoch [149], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [150], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [151], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [152], LR [1e-05], Loss[Train: 0.031, Valid: 0.033], R2[Train: 0.972, Valid: 0.970]
# Epoch [153], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [154], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [155], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [156], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [157], LR [1e-05], Loss[Train: 0.031, Valid: 0.032], R2[Train: 0.972, Valid: 0.971]
# Epoch [158], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [159], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [160], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.972]
# Epoch [161], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [162], LR [1e-05], Loss[Train: 0.031, Valid: 0.032], R2[Train: 0.972, Valid: 0.970]
# Epoch [163], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [164], LR [1e-05], Loss[Train: 0.031, Valid: 0.032], R2[Train: 0.972, Valid: 0.971]
# Epoch [165], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [166], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.972]
# Epoch [167], LR [1e-05], Loss[Train: 0.030, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [168], LR [1e-05], Loss[Train: 0.030, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [169], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [170], LR [1e-05], Loss[Train: 0.031, Valid: 0.032], R2[Train: 0.972, Valid: 0.971]
# Epoch [171], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.972]
# Epoch [172], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [173], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [174], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [175], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.972]
# Epoch [176], LR [1e-05], Loss[Train: 0.031, Valid: 0.033], R2[Train: 0.972, Valid: 0.970]
# Epoch [177], LR [1e-05], Loss[Train: 0.030, Valid: 0.032], R2[Train: 0.972, Valid: 0.970]
# Epoch [178], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.972]
# Epoch [179], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [180], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.972]
# Epoch [181], LR [1e-05], Loss[Train: 0.031, Valid: 0.033], R2[Train: 0.972, Valid: 0.970]
# Epoch [182], LR [1e-05], Loss[Train: 0.030, Valid: 0.031], R2[Train: 0.972, Valid: 0.972]
# Epoch [183], LR [1e-05], Loss[Train: 0.030, Valid: 0.032], R2[Train: 0.972, Valid: 0.971]
# Epoch [184], LR [1e-05], Loss[Train: 0.030, Valid: 0.031], R2[Train: 0.972, Valid: 0.972]
# Epoch [185], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [186], LR [1e-05], Loss[Train: 0.030, Valid: 0.031], R2[Train: 0.972, Valid: 0.972]
# Epoch [187], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.972]
# Epoch [188], LR [1e-05], Loss[Train: 0.030, Valid: 0.031], R2[Train: 0.972, Valid: 0.972]
# Epoch [189], LR [1e-05], Loss[Train: 0.030, Valid: 0.031], R2[Train: 0.972, Valid: 0.972]
# Epoch [190], LR [1e-05], Loss[Train: 0.030, Valid: 0.031], R2[Train: 0.972, Valid: 0.972]
# Epoch [191], LR [1e-05], Loss[Train: 0.030, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [192], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.972]
# Epoch [193], LR [1e-05], Loss[Train: 0.030, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [194], LR [1e-05], Loss[Train: 0.030, Valid: 0.031], R2[Train: 0.972, Valid: 0.972]
# Epoch [195], LR [1e-05], Loss[Train: 0.030, Valid: 0.031], R2[Train: 0.972, Valid: 0.972]
# Epoch [196], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Epoch [197], LR [1e-05], Loss[Train: 0.031, Valid: 0.033], R2[Train: 0.972, Valid: 0.970]
# Epoch [198], LR [1e-05], Loss[Train: 0.030, Valid: 0.031], R2[Train: 0.972, Valid: 0.972]
# Epoch [199], LR [1e-05], Loss[Train: 0.031, Valid: 0.031], R2[Train: 0.972, Valid: 0.972]
# Epoch [200], LR [1e-05], Loss[Train: 0.030, Valid: 0.031], R2[Train: 0.972, Valid: 0.971]
# Final Valid Loss: 0.0309

# %%
def plot_losses(train_losses, valid_losses, epoch_num, output_dir):
    plt.figure(figsize=(5, 5), dpi=150)
    plt.rcParams["font.serif"] = ["Times New Roman"]
    plt.rcParams["font.size"] = 12

    plt.plot(np.array(train_losses), label="Train")
    plt.plot(np.array(valid_losses), label="Validation")
    plt.legend()
    plt.xlabel("Epoch")
    plt.ylabel("MSE Loss")
    plt.yscale("log")
    plt.xlim(0, len(train_losses))
    plt.tight_layout()

    os.makedirs(output_dir, exist_ok=True)
    plt.savefig(os.path.join(output_dir, "training_loss.png"))
    plt.show()


plot_losses(train_losses, valid_losses, epoch_num, args.save_model_dir)

# %% [markdown]
# ## Save and reload best checkpoint

# %%
best_model_path = os.path.join(args.save_model_dir, f"epoch_{len(train_losses)}.pt")
torch.save(best_state_dict, best_model_path)
print(f"Saved best model to: {best_model_path}")

model.load_state_dict(best_state_dict)
# Out:
# Saved best model to: /kaggle/working/saved_model/epoch_200.pt
# <All keys matched successfully>

# %% [markdown]
# ## 4. Evaluate on train / validation / test

# %%
R2, bias = evaluate_model(model, train_loader, device, args.cover_interval, overlap, args.save_model_dir, split_name="train")
# Out:
# Train R2 for E: 0.9726612567901611
# Train Bias (mean residual): 0.0046

# %%
R2, bias = evaluate_model(model, valid_loader, device, args.cover_interval, overlap, args.save_model_dir, split_name="validation")
# Out:
# Validation R2 for E: 0.9717463254928589
# Validation Bias (mean residual): 0.0073

# %%
R2, bias = evaluate_model(model, test_loader, device, args.cover_interval, overlap, args.save_model_dir, split_name="test")
# Out:
# Test R2 for E: 0.9741080403327942
# Test Bias (mean residual): 0.0047
